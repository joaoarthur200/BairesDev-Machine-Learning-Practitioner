# %% [markdown]
# <a href="https://colab.research.google.com/github/igornunespatricio/BairesDev-Machine-Learning-Practitioner/blob/main/dimensionality_reduction_colored_image_to_grayscale_binarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open('/content/lenna.png')
plt.imshow(image)
plt.show()

# %%
gray_image = image.convert('L')
plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
# another way to transform image to grayscale
import numpy as np

image_array = np.array(image)
gray_image = 0.2989 * image_array[:, :, 0] + 0.5870 * image_array[:, :, 1] + 0.1140 * image_array[:, :, 2]
plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
threshold = 128
binary_image = gray_image.point(lambda x: 0 if x < threshold else 255, '1')
plt.imshow(binary_image, cmap='gray')
plt.show()
